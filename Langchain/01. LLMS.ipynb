# %%
# !pip install langchain-openai python-dotenv openai

# %% [markdown]
# ### OpenAI LLM

# %%
from langchain_openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

llm = OpenAI(model='gpt-3.5-turbo-instruct')

result = llm.invoke("What is the capital of India")

print(result)
# Out:
# The capital of India is New Delhi.

# %% [markdown]
# ### OpenAI ChatModel

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv()

model = ChatOpenAI(model='gpt-4', temperature=1.5, max_completion_tokens=10)

result = model.invoke("Write a 5 line poem on cricket")

print(result.content)
# Out:
# On the lush green field lies our scraped heart,

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

load_dotenv()

model = ChatOpenAI(
    model='gpt-4.1',
    temperature=1.5,
    max_completion_tokens=50
)

messages = [
    SystemMessage(content="You are a helpful AI assistant."),
    
    HumanMessage(content="Hi"),
    
    AIMessage(content="Hello! How can I help you today?"),
    
    HumanMessage(content="Write a 5 line poem on cricket")
]

result = model.invoke(messages)

print(result.content)
# Out:
# Leather meets willow in the morning sun,
# Cheering crowds when the match’s begun,
# Stumps stand tall as the bowlers run,
# Triumph and hope in every single run,
# Cricket unites all, no matter where you

# %% [markdown]
# ### Anthropic ChatModel

# %%
# pip install langchain-anthropic
from langchain_anthropic import ChatAnthropic
from dotenv import load_dotenv

load_dotenv()

model = ChatAnthropic(model='claude-3-5-sonnet-20241022')

result = model.invoke('What is the capital of India')

print(result.content)

# %%
# !pip install langchain-huggingface

# %% [markdown]
# ### Open Source model using Hugging Face API

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from dotenv import load_dotenv
import os

load_dotenv()

llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-R1-0528",
    task="text-generation",
    provider="auto",
    huggingfacehub_api_token=os.getenv("HUGGINGFACEHUB_API_TOKEN"),
)

model = ChatHuggingFace(llm=llm)

result = model.invoke("What is the capital of India?")
print(result.content)
# Out:
# The capital of India is **New Delhi**.
#
# Here are a few key details:
#
# 1.  **Location:** New Delhi is located within the larger **National Capital Territory of Delhi** (often just called "Delhi").
# 2.  **Role:** It serves as the seat of all three branches of the Government of India: the executive (Rashtrapati Bhavan, Parliament House), the legislature (Sansad Bhavan), and the judiciary (Supreme Court).
# 3.  **Planned City:** New Delhi was specifically designed and built in the early 20th century (inaugurated in 1931) to serve as the new capital of British India, replacing Calcutta (Kolkata). It retained its status as the capital after India gained independence in 1947.
#
# So, while people often say "Delhi" is the capital, the precise administrative capital is **New Delhi**.
